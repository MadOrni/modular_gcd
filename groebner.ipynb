# %%
from IPython.display import display, Math, Latex
import time
import random
    
P.<x ,y ,z > = PolynomialRing ( FiniteField (7) , order ="lex")
primeRing = PolynomialRing(FiniteField(random_prime(2^24,False,2^22)), 'x' ,order ="lex")


#für den ring , variablen festelgen 
#

display(Math(latex(P)))

display(Math(latex(x ^2* y*z ^2))) 
display(Math(latex( x*y ^3* z)))
# Out:
# $\displaystyle \Bold{F}_{7}[x, y, z]$
# $\displaystyle x^{2} y z^{2}$
# $\displaystyle x y^{3} z$

# %%
def Buchberger(list_of_polynoms):
    G = list_of_polynoms
    GS = [];
    while GS != G
        GS = G
            for polynom in GS:
                if pol1 != pol2:
                    create_s_polynom(pol1, pol2)
                    r = pol1.q_rem(pol2)
                    if r != 0:
                        G.add(r)

# %%
def create_s_polynom(pol1, pol2):
    Lt_pol1 = pol1
    Lt_pol2 = pol2
    kgV = 1 #höchster grad jeder varaible von den termen
